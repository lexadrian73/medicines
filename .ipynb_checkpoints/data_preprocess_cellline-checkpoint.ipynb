# %% [markdown]
# # Read DATA

# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import numpy as np
import zipfile
import re
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.svm import OneClassSVM
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial import distance

# %%
file = 'data/abstracts.zip'
with zipfile.ZipFile(file, 'r') as zf:
    with zf.open('abstracts.csv', 'r') as f:
        df_r = pd.read_csv(f, index_col = 0)

# %%
numero_filas = df_r.shape[0]
print("Papers", numero_filas)
df_r.columns
# Out:
# Papers 113008
# Index(['cell_line', 'pubmedid', 'title', 'abstract'], dtype='object')

# %%
def get_cell_lines(dataframe, num):
    cell_lines = dataframe['cell_line'].unique()[:num]
    rows = dataframe[dataframe['cell_line'].isin(cell_lines)].reset_index(drop=True)
    return rows

# %%
#Limitar dataset 
df = get_cell_lines(df_r, 25)
print(df)
# Out:
#      cell_line  pubmedid                                              title  \
# 0    CVCL_0028  33040078  Splicing factor SF3B1 promotes endometrial can...
# 1    CVCL_0028  34476599  Sirtuin 2 promotes cell stemness and MEK/ERK s...
# 2    CVCL_0028  35401936  Role of the prorenin receptor in endometrial c...
# 3    CVCL_0028  32431202  NLRC5 promotes cell migration and invasion by ...
# 4    CVCL_0028  24526410  GRP78 mediates cell growth and invasiveness in...
# ..         ...       ...                                                ...
# 290  CVCL_0197  28745235  Effects of Ascorbic Acid on Tax, NF-κB and MMP...
# 291  CVCL_0197  12850476  Localization of HTLV-I tax proviral DNA in mon...
# 292  CVCL_0197   1373751  Human T lymphotropic virus types I- and II-spe...
# 293  CVCL_0197   2398525  Molecular cloning and characterization of a cD...
# 294  CVCL_0197   1380895  Induction of strong homotypic adhesion in huma...
#
#                                               abstract
# 0    Although endometrial cancer is the most common...
# 1    Sirtuin 2 (SIRT2) is functionally important in...
# 2    Endometrial cancer is the most diagnosed gynec...
# 3    NOD-like receptor family caspase recruitment d...
# 4    Recent studies have indicated that endoplasmic...
# ..                                                 ...
# 290  HTLV1 is a retrovirus that infects CD4-positiv...
# 291  The tax sequence of HTLV-I is demonstrable in ...
# 292  Antibody-dependent cellular cytotoxicity (ADCC...
# 293  To identify gene products that might be involv...
# 294  To identify the cellular receptors and other c...
#
# [295 rows x 4 columns]

# %% [markdown]
# ## Preprocesamiento

# %%
def preprocess_text(text):
    text = text.lower()
    tokenizer = RegexpTokenizer(r'\w+')
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    tokens = tokenizer.tokenize(text)
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    tokens = [word for word in tokens if not re.match(r'\d+', word)]
    processed_text = ' '.join(tokens)
    return processed_text

df['abstract_p'] = df['abstract'].apply(preprocess_text)
#df.to_csv('data/abstracts.csv', index=False)
print(df)
# Out:
#      cell_line  pubmedid                                              title  \
# 0    CVCL_0028  33040078  Splicing factor SF3B1 promotes endometrial can...
# 1    CVCL_0028  34476599  Sirtuin 2 promotes cell stemness and MEK/ERK s...
# 2    CVCL_0028  35401936  Role of the prorenin receptor in endometrial c...
# 3    CVCL_0028  32431202  NLRC5 promotes cell migration and invasion by ...
# 4    CVCL_0028  24526410  GRP78 mediates cell growth and invasiveness in...
# ..         ...       ...                                                ...
# 290  CVCL_0197  28745235  Effects of Ascorbic Acid on Tax, NF-κB and MMP...
# 291  CVCL_0197  12850476  Localization of HTLV-I tax proviral DNA in mon...
# 292  CVCL_0197   1373751  Human T lymphotropic virus types I- and II-spe...
# 293  CVCL_0197   2398525  Molecular cloning and characterization of a cD...
# 294  CVCL_0197   1380895  Induction of strong homotypic adhesion in huma...
#
#                                               abstract  \
# 0    Although endometrial cancer is the most common...
# 1    Sirtuin 2 (SIRT2) is functionally important in...
# 2    Endometrial cancer is the most diagnosed gynec...
# 3    NOD-like receptor family caspase recruitment d...
# 4    Recent studies have indicated that endoplasmic...
# ..                                                 ...
# 290  HTLV1 is a retrovirus that infects CD4-positiv...
# 291  The tax sequence of HTLV-I is demonstrable in ...
# 292  Antibody-dependent cellular cytotoxicity (ADCC...
# 293  To identify gene products that might be involv...
# 294  To identify the cellular receptors and other c...
#
#                                             abstract_p
# 0    although endometrial cancer common cancer fema...
# 1    sirtuin sirt2 functionally important cancer pr...
# 2    endometrial cancer diagnosed gynecological mal...
# 3    nod like receptor family caspase recruitment d...
# 4    recent study indicated endoplasmic reticulum s...
# ..                                                 ...
# 290  htlv1 retrovirus infects cd4 positive cell lea...
# 291  tax sequence htlv demonstrable skin blood mono...
# 292  antibody dependent cellular cytotoxicity adcc ...
# 293  identify gene product might involved leukemoge...
# 294  identify cellular receptor cell surface molecu...
#
# [295 rows x 5 columns]

# %%
a = "plays"
print(preprocess_text(a))
# Out:
# play

# %%
unique_values = df['cell_line'].unique()
print(len(unique_values))
# Out:
# 25

# %% [markdown]
# ## TF IDF

# %%
corpus = df['abstract_p'].tolist()

vectorizer = TfidfVectorizer()
X_tfidf    = vectorizer.fit_transform(corpus)

# %% [markdown]
# ## SVDD

# %%
category_centroids = {}
category_radii = {}

for category in df['cell_line'].unique():
    support_vectors = X_tfidf[df['cell_line'] == category]

    centroid = np.mean(support_vectors, axis=0)
    category_centroids[category] = centroid

    distances = np.linalg.norm(support_vectors - centroid, axis=1)
    
    radius = np.mean(distances)
    category_radii[category] = radius

for category, centroid in category_centroids.items():
    print(f"cell_line: {category}")
    print(f"Centro: {centroid}")
    print(f"Radio: {category_radii[category]}")
    print()
# Out:
# cell_line: CVCL_0028
# Centro: [[0.         0.         0.         ... 0.         0.0044869  0.00701365]]
# Radio: 0.9222394183005846
#
# cell_line: CVCL_0080
# Centro: [[0.         0.         0.         ... 0.         0.00642791 0.00685484]]
# Radio: 0.9316592953966272
#
# cell_line: CVCL_0081
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.8949298686218217
#
# cell_line: CVCL_0082
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.8791341246784244
#
# cell_line: CVCL_0107
# Centro: [[0.         0.00663711 0.         ... 0.         0.         0.00363691]]
# Radio: 0.9197991751784799
#
# cell_line: CVCL_0110
# Centro: [[0.         0.         0.00333432 ... 0.         0.         0.        ]]
# Radio: 0.9321831124533062
#
# cell_line: CVCL_0113
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.8970772778178572
#
# cell_line: CVCL_0115
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.9101104428370347
#
# cell_line: CVCL_0128
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.840030033601982
#
# cell_line: CVCL_0135
# Centro: [[0.         0.         0.         ... 0.         0.         0.00417392]]
# Radio: 0.8916759056913418
#
# cell_line: CVCL_0136
# Centro: [[0.         0.         0.         ... 0.00970468 0.         0.0380016 ]]
# Radio: 0.894633092638601
#
# cell_line: CVCL_0138
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.8797466280074778
#
# cell_line: CVCL_0141
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.9051822753813106
#
# cell_line: CVCL_0144
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.9298902213538245
#
# cell_line: CVCL_0147
# Centro: [[0.         0.         0.02229494 ... 0.         0.         0.        ]]
# Radio: 0.6865175615286332
#
# cell_line: CVCL_0153
# Centro: [[0.00454104 0.         0.         ... 0.         0.         0.00524315]]
# Radio: 0.901496225521769
#
# cell_line: CVCL_0164
# Centro: [[0.         0.         0.         ... 0.         0.         0.00923127]]
# Radio: 0.9324597267557885
#
# cell_line: CVCL_0165
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.8922001538830199
#
# cell_line: CVCL_0171
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.9115531338755638
#
# cell_line: CVCL_0181
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.9178995244084697
#
# cell_line: CVCL_0187
# Centro: [[0.        0.        0.        ... 0.        0.        0.0040284]]
# Radio: 0.9127080964648171
#
# cell_line: CVCL_0193
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.9064356443444912
#
# cell_line: CVCL_0195
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.9217754160688109
#
# cell_line: CVCL_0196
# Centro: [[0. 0. 0. ... 0. 0. 0.]]
# Radio: 0.880117824673294
#
# cell_line: CVCL_0197
# Centro: [[0.04817795 0.         0.         ... 0.         0.         0.        ]]
# Radio: 0.9139199872215289

# %%
categorias_solapadas = []

# Itera sobre las categorías y compara las distancias entre los centros de las esferas
for category1, centroid1 in category_centroids.items():
    for category2, centroid2 in category_centroids.items():
        if category1 != category2:
            # Calcula la distancia entre los centros de las esferas
            distancia = np.linalg.norm(centroid1 - centroid2)

            # Verifica si la distancia es menor o igual al radio de la segunda esfera
            if distancia <= category_radii[category2]:
                # La categoría 1 está dentro de la categoría 2
                categorias_solapadas.append((category1, category2))

# Imprime las categorías solapadas
for categoria1, categoria2 in categorias_solapadas:
    print(f"{categoria1} está dentro de {categoria2}")
# Out:
# CVCL_0028 está dentro de CVCL_0080
# CVCL_0028 está dentro de CVCL_0081
# CVCL_0028 está dentro de CVCL_0082
# CVCL_0028 está dentro de CVCL_0107
# CVCL_0028 está dentro de CVCL_0110
# CVCL_0028 está dentro de CVCL_0113
# CVCL_0028 está dentro de CVCL_0115
# CVCL_0028 está dentro de CVCL_0128
# CVCL_0028 está dentro de CVCL_0135
# CVCL_0028 está dentro de CVCL_0136
# CVCL_0028 está dentro de CVCL_0138
# CVCL_0028 está dentro de CVCL_0141
# CVCL_0028 está dentro de CVCL_0144
# CVCL_0028 está dentro de CVCL_0153
# CVCL_0028 está dentro de CVCL_0164
# CVCL_0028 está dentro de CVCL_0165
# CVCL_0028 está dentro de CVCL_0171
# CVCL_0028 está dentro de CVCL_0181
# CVCL_0028 está dentro de CVCL_0187
# CVCL_0028 está dentro de CVCL_0193
# CVCL_0028 está dentro de CVCL_0195
# CVCL_0028 está dentro de CVCL_0196
# CVCL_0028 está dentro de CVCL_0197
# CVCL_0080 está dentro de CVCL_0028
# CVCL_0080 está dentro de CVCL_0081
# CVCL_0080 está dentro de CVCL_0082
# CVCL_0080 está dentro de CVCL_0107
# CVCL_0080 está dentro de CVCL_0110
# CVCL_0080 está dentro de CVCL_0113
# CVCL_0080 está dentro de CVCL_0115
# CVCL_0080 está dentro de CVCL_0128
# CVCL_0080 está dentro de CVCL_0135
# CVCL_0080 está dentro de CVCL_0136
# CVCL_0080 está dentro de CVCL_0138
# CVCL_0080 está dentro de CVCL_0141
# CVCL_0080 está dentro de CVCL_0144
# CVCL_0080 está dentro de CVCL_0153
# CVCL_0080 está dentro de CVCL_0164
# CVCL_0080 está dentro de CVCL_0165
# CVCL_0080 está dentro de CVCL_0171
# CVCL_0080 está dentro de CVCL_0181
# CVCL_0080 está dentro de CVCL_0187
# CVCL_0080 está dentro de CVCL_0193
# CVCL_0080 está dentro de CVCL_0195
# CVCL_0080 está dentro de CVCL_0196
# CVCL_0080 está dentro de CVCL_0197
# CVCL_0081 está dentro de CVCL_0028
# CVCL_0081 está dentro de CVCL_0080
# CVCL_0081 está dentro de CVCL_0082
# CVCL_0081 está dentro de CVCL_0107
# CVCL_0081 está dentro de CVCL_0110
# CVCL_0081 está dentro de CVCL_0113
# CVCL_0081 está dentro de CVCL_0115
# CVCL_0081 está dentro de CVCL_0128
# CVCL_0081 está dentro de CVCL_0135
# CVCL_0081 está dentro de CVCL_0136
# CVCL_0081 está dentro de CVCL_0138
# CVCL_0081 está dentro de CVCL_0141
# CVCL_0081 está dentro de CVCL_0144
# CVCL_0081 está dentro de CVCL_0153
# CVCL_0081 está dentro de CVCL_0164
# CVCL_0081 está dentro de CVCL_0165
# CVCL_0081 está dentro de CVCL_0171
# CVCL_0081 está dentro de CVCL_0181
# CVCL_0081 está dentro de CVCL_0187
# CVCL_0081 está dentro de CVCL_0193
# CVCL_0081 está dentro de CVCL_0195
# CVCL_0081 está dentro de CVCL_0196
# CVCL_0081 está dentro de CVCL_0197
# CVCL_0082 está dentro de CVCL_0028
# CVCL_0082 está dentro de CVCL_0080
# CVCL_0082 está dentro de CVCL_0081
# CVCL_0082 está dentro de CVCL_0107
# CVCL_0082 está dentro de CVCL_0110
# CVCL_0082 está dentro de CVCL_0113
# CVCL_0082 está dentro de CVCL_0115
# CVCL_0082 está dentro de CVCL_0128
# CVCL_0082 está dentro de CVCL_0135
# CVCL_0082 está dentro de CVCL_0136
# CVCL_0082 está dentro de CVCL_0138
# CVCL_0082 está dentro de CVCL_0141
# CVCL_0082 está dentro de CVCL_0144
# CVCL_0082 está dentro de CVCL_0153
# CVCL_0082 está dentro de CVCL_0164
# CVCL_0082 está dentro de CVCL_0165
# CVCL_0082 está dentro de CVCL_0171
# CVCL_0082 está dentro de CVCL_0181
# CVCL_0082 está dentro de CVCL_0187
# CVCL_0082 está dentro de CVCL_0193
# CVCL_0082 está dentro de CVCL_0195
# CVCL_0082 está dentro de CVCL_0196
# CVCL_0082 está dentro de CVCL_0197
# CVCL_0107 está dentro de CVCL_0028
# CVCL_0107 está dentro de CVCL_0080
# CVCL_0107 está dentro de CVCL_0081
# CVCL_0107 está dentro de CVCL_0082
# CVCL_0107 está dentro de CVCL_0110
# CVCL_0107 está dentro de CVCL_0113
# CVCL_0107 está dentro de CVCL_0115
# CVCL_0107 está dentro de CVCL_0128
# CVCL_0107 está dentro de CVCL_0135
# CVCL_0107 está dentro de CVCL_0136
# CVCL_0107 está dentro de CVCL_0138
# CVCL_0107 está dentro de CVCL_0141
# CVCL_0107 está dentro de CVCL_0144
# CVCL_0107 está dentro de CVCL_0153
# CVCL_0107 está dentro de CVCL_0164
# CVCL_0107 está dentro de CVCL_0165
# CVCL_0107 está dentro de CVCL_0171
# CVCL_0107 está dentro de CVCL_0181
# CVCL_0107 está dentro de CVCL_0187
# CVCL_0107 está dentro de CVCL_0193
# CVCL_0107 está dentro de CVCL_0195
# CVCL_0107 está dentro de CVCL_0196
# CVCL_0107 está dentro de CVCL_0197
# CVCL_0110 está dentro de CVCL_0028
# CVCL_0110 está dentro de CVCL_0080
# CVCL_0110 está dentro de CVCL_0081
# CVCL_0110 está dentro de CVCL_0082
# CVCL_0110 está dentro de CVCL_0107
# CVCL_0110 está dentro de CVCL_0113
# CVCL_0110 está dentro de CVCL_0115
# CVCL_0110 está dentro de CVCL_0128
# CVCL_0110 está dentro de CVCL_0135
# CVCL_0110 está dentro de CVCL_0136
# CVCL_0110 está dentro de CVCL_0138
# CVCL_0110 está dentro de CVCL_0141
# CVCL_0110 está dentro de CVCL_0144
# CVCL_0110 está dentro de CVCL_0153
# CVCL_0110 está dentro de CVCL_0164
# CVCL_0110 está dentro de CVCL_0165
# CVCL_0110 está dentro de CVCL_0171
# CVCL_0110 está dentro de CVCL_0181
# CVCL_0110 está dentro de CVCL_0187
# CVCL_0110 está dentro de CVCL_0193
# CVCL_0110 está dentro de CVCL_0195
# CVCL_0110 está dentro de CVCL_0196
# CVCL_0110 está dentro de CVCL_0197
# CVCL_0113 está dentro de CVCL_0028
# CVCL_0113 está dentro de CVCL_0080
# CVCL_0113 está dentro de CVCL_0081
# CVCL_0113 está dentro de CVCL_0082
# CVCL_0113 está dentro de CVCL_0107
# CVCL_0113 está dentro de CVCL_0110
# CVCL_0113 está dentro de CVCL_0115
# CVCL_0113 está dentro de CVCL_0128
# CVCL_0113 está dentro de CVCL_0135
# CVCL_0113 está dentro de CVCL_0136
# CVCL_0113 está dentro de CVCL_0138
# CVCL_0113 está dentro de CVCL_0141
# CVCL_0113 está dentro de CVCL_0144
# CVCL_0113 está dentro de CVCL_0153
# CVCL_0113 está dentro de CVCL_0164
# CVCL_0113 está dentro de CVCL_0165
# CVCL_0113 está dentro de CVCL_0171
# CVCL_0113 está dentro de CVCL_0181
# CVCL_0113 está dentro de CVCL_0187
# CVCL_0113 está dentro de CVCL_0193
# CVCL_0113 está dentro de CVCL_0195
# CVCL_0113 está dentro de CVCL_0196
# CVCL_0113 está dentro de CVCL_0197
# CVCL_0115 está dentro de CVCL_0028
# CVCL_0115 está dentro de CVCL_0080
# CVCL_0115 está dentro de CVCL_0081
# CVCL_0115 está dentro de CVCL_0082
# CVCL_0115 está dentro de CVCL_0107
# CVCL_0115 está dentro de CVCL_0110
# CVCL_0115 está dentro de CVCL_0113
# CVCL_0115 está dentro de CVCL_0128
# CVCL_0115 está dentro de CVCL_0135
# CVCL_0115 está dentro de CVCL_0136
# CVCL_0115 está dentro de CVCL_0138
# CVCL_0115 está dentro de CVCL_0141
# CVCL_0115 está dentro de CVCL_0144
# CVCL_0115 está dentro de CVCL_0153
# CVCL_0115 está dentro de CVCL_0164
# CVCL_0115 está dentro de CVCL_0165
# CVCL_0115 está dentro de CVCL_0171
# CVCL_0115 está dentro de CVCL_0181
# CVCL_0115 está dentro de CVCL_0187
# CVCL_0115 está dentro de CVCL_0193
# CVCL_0115 está dentro de CVCL_0195
# CVCL_0115 está dentro de CVCL_0196
# CVCL_0115 está dentro de CVCL_0197
# CVCL_0128 está dentro de CVCL_0028
# CVCL_0128 está dentro de CVCL_0080
# CVCL_0128 está dentro de CVCL_0081
# CVCL_0128 está dentro de CVCL_0082
# CVCL_0128 está dentro de CVCL_0107
# CVCL_0128 está dentro de CVCL_0110
# CVCL_0128 está dentro de CVCL_0113
# CVCL_0128 está dentro de CVCL_0115
# CVCL_0128 está dentro de CVCL_0135
# CVCL_0128 está dentro de CVCL_0136
# CVCL_0128 está dentro de CVCL_0138
# CVCL_0128 está dentro de CVCL_0141
# CVCL_0128 está dentro de CVCL_0144
# CVCL_0128 está dentro de CVCL_0153
# CVCL_0128 está dentro de CVCL_0164
# CVCL_0128 está dentro de CVCL_0165
# CVCL_0128 está dentro de CVCL_0171
# CVCL_0128 está dentro de CVCL_0181
# CVCL_0128 está dentro de CVCL_0187
# CVCL_0128 está dentro de CVCL_0193
# CVCL_0128 está dentro de CVCL_0195
# CVCL_0128 está dentro de CVCL_0196
# CVCL_0128 está dentro de CVCL_0197
# CVCL_0135 está dentro de CVCL_0028
# CVCL_0135 está dentro de CVCL_0080
# CVCL_0135 está dentro de CVCL_0081
# CVCL_0135 está dentro de CVCL_0082
# CVCL_0135 está dentro de CVCL_0107
# CVCL_0135 está dentro de CVCL_0110
# CVCL_0135 está dentro de CVCL_0113
# CVCL_0135 está dentro de CVCL_0115
# CVCL_0135 está dentro de CVCL_0128
# CVCL_0135 está dentro de CVCL_0136
# CVCL_0135 está dentro de CVCL_0138
# CVCL_0135 está dentro de CVCL_0141
# CVCL_0135 está dentro de CVCL_0144
# CVCL_0135 está dentro de CVCL_0153
# CVCL_0135 está dentro de CVCL_0164
# CVCL_0135 está dentro de CVCL_0165
# CVCL_0135 está dentro de CVCL_0171
# CVCL_0135 está dentro de CVCL_0181
# CVCL_0135 está dentro de CVCL_0187
# CVCL_0135 está dentro de CVCL_0193
# CVCL_0135 está dentro de CVCL_0195
# CVCL_0135 está dentro de CVCL_0196
# CVCL_0135 está dentro de CVCL_0197
# CVCL_0136 está dentro de CVCL_0028
# CVCL_0136 está dentro de CVCL_0080
# CVCL_0136 está dentro de CVCL_0081
# CVCL_0136 está dentro de CVCL_0082
# CVCL_0136 está dentro de CVCL_0107
# CVCL_0136 está dentro de CVCL_0110
# CVCL_0136 está dentro de CVCL_0113
# CVCL_0136 está dentro de CVCL_0115
# CVCL_0136 está dentro de CVCL_0128
# CVCL_0136 está dentro de CVCL_0135
# CVCL_0136 está dentro de CVCL_0138
# CVCL_0136 está dentro de CVCL_0141
# CVCL_0136 está dentro de CVCL_0144
# CVCL_0136 está dentro de CVCL_0153
# CVCL_0136 está dentro de CVCL_0164
# CVCL_0136 está dentro de CVCL_0165
# CVCL_0136 está dentro de CVCL_0171
# CVCL_0136 está dentro de CVCL_0181
# CVCL_0136 está dentro de CVCL_0187
# CVCL_0136 está dentro de CVCL_0193
# CVCL_0136 está dentro de CVCL_0195
# CVCL_0136 está dentro de CVCL_0196
# CVCL_0136 está dentro de CVCL_0197
# CVCL_0138 está dentro de CVCL_0028
# CVCL_0138 está dentro de CVCL_0080
# CVCL_0138 está dentro de CVCL_0081
# CVCL_0138 está dentro de CVCL_0082
# CVCL_0138 está dentro de CVCL_0107
# CVCL_0138 está dentro de CVCL_0110
# CVCL_0138 está dentro de CVCL_0113
# CVCL_0138 está dentro de CVCL_0115
# CVCL_0138 está dentro de CVCL_0128
# CVCL_0138 está dentro de CVCL_0135
# CVCL_0138 está dentro de CVCL_0136
# CVCL_0138 está dentro de CVCL_0141
# CVCL_0138 está dentro de CVCL_0144
# CVCL_0138 está dentro de CVCL_0153
# CVCL_0138 está dentro de CVCL_0164
# CVCL_0138 está dentro de CVCL_0165
# CVCL_0138 está dentro de CVCL_0171
# CVCL_0138 está dentro de CVCL_0181
# CVCL_0138 está dentro de CVCL_0187
# CVCL_0138 está dentro de CVCL_0193
# CVCL_0138 está dentro de CVCL_0195
# CVCL_0138 está dentro de CVCL_0196
# CVCL_0138 está dentro de CVCL_0197
# CVCL_0141 está dentro de CVCL_0028
# CVCL_0141 está dentro de CVCL_0080
# CVCL_0141 está dentro de CVCL_0081
# CVCL_0141 está dentro de CVCL_0082
# CVCL_0141 está dentro de CVCL_0107
# CVCL_0141 está dentro de CVCL_0110
# CVCL_0141 está dentro de CVCL_0113
# CVCL_0141 está dentro de CVCL_0115
# CVCL_0141 está dentro de CVCL_0128
# CVCL_0141 está dentro de CVCL_0135
# CVCL_0141 está dentro de CVCL_0136
# CVCL_0141 está dentro de CVCL_0138
# CVCL_0141 está dentro de CVCL_0144
# CVCL_0141 está dentro de CVCL_0153
# CVCL_0141 está dentro de CVCL_0164
# CVCL_0141 está dentro de CVCL_0165
# CVCL_0141 está dentro de CVCL_0171
# CVCL_0141 está dentro de CVCL_0181
# CVCL_0141 está dentro de CVCL_0187
# CVCL_0141 está dentro de CVCL_0193
# CVCL_0141 está dentro de CVCL_0195
# CVCL_0141 está dentro de CVCL_0196
# CVCL_0141 está dentro de CVCL_0197
# CVCL_0144 está dentro de CVCL_0028
# CVCL_0144 está dentro de CVCL_0080
# CVCL_0144 está dentro de CVCL_0081
# CVCL_0144 está dentro de CVCL_0082
# CVCL_0144 está dentro de CVCL_0107
# CVCL_0144 está dentro de CVCL_0110
# CVCL_0144 está dentro de CVCL_0113
# CVCL_0144 está dentro de CVCL_0115
# CVCL_0144 está dentro de CVCL_0128
# CVCL_0144 está dentro de CVCL_0135
# CVCL_0144 está dentro de CVCL_0136
# CVCL_0144 está dentro de CVCL_0138
# CVCL_0144 está dentro de CVCL_0141
# CVCL_0144 está dentro de CVCL_0153
# CVCL_0144 está dentro de CVCL_0164
# CVCL_0144 está dentro de CVCL_0165
# CVCL_0144 está dentro de CVCL_0171
# CVCL_0144 está dentro de CVCL_0181
# CVCL_0144 está dentro de CVCL_0187
# CVCL_0144 está dentro de CVCL_0193
# CVCL_0144 está dentro de CVCL_0195
# CVCL_0144 está dentro de CVCL_0196
# CVCL_0144 está dentro de CVCL_0197
# CVCL_0147 está dentro de CVCL_0028
# CVCL_0147 está dentro de CVCL_0080
# CVCL_0147 está dentro de CVCL_0081
# CVCL_0147 está dentro de CVCL_0082
# CVCL_0147 está dentro de CVCL_0107
# CVCL_0147 está dentro de CVCL_0110
# CVCL_0147 está dentro de CVCL_0113
# CVCL_0147 está dentro de CVCL_0115
# CVCL_0147 está dentro de CVCL_0128
# CVCL_0147 está dentro de CVCL_0135
# CVCL_0147 está dentro de CVCL_0136
# CVCL_0147 está dentro de CVCL_0138
# CVCL_0147 está dentro de CVCL_0141
# CVCL_0147 está dentro de CVCL_0144
# CVCL_0147 está dentro de CVCL_0153
# CVCL_0147 está dentro de CVCL_0164
# CVCL_0147 está dentro de CVCL_0165
# CVCL_0147 está dentro de CVCL_0171
# CVCL_0147 está dentro de CVCL_0181
# CVCL_0147 está dentro de CVCL_0187
# CVCL_0147 está dentro de CVCL_0193
# CVCL_0147 está dentro de CVCL_0195
# CVCL_0147 está dentro de CVCL_0196
# CVCL_0147 está dentro de CVCL_0197
# CVCL_0153 está dentro de CVCL_0028
# CVCL_0153 está dentro de CVCL_0080
# CVCL_0153 está dentro de CVCL_0081
# CVCL_0153 está dentro de CVCL_0082
# CVCL_0153 está dentro de CVCL_0107
# CVCL_0153 está dentro de CVCL_0110
# CVCL_0153 está dentro de CVCL_0113
# CVCL_0153 está dentro de CVCL_0115
# CVCL_0153 está dentro de CVCL_0128
# CVCL_0153 está dentro de CVCL_0135
# CVCL_0153 está dentro de CVCL_0136
# CVCL_0153 está dentro de CVCL_0138
# CVCL_0153 está dentro de CVCL_0141
# CVCL_0153 está dentro de CVCL_0144
# CVCL_0153 está dentro de CVCL_0164
# CVCL_0153 está dentro de CVCL_0165
# CVCL_0153 está dentro de CVCL_0171
# CVCL_0153 está dentro de CVCL_0181
# CVCL_0153 está dentro de CVCL_0187
# CVCL_0153 está dentro de CVCL_0193
# CVCL_0153 está dentro de CVCL_0195
# CVCL_0153 está dentro de CVCL_0196
# CVCL_0153 está dentro de CVCL_0197
# CVCL_0164 está dentro de CVCL_0028
# CVCL_0164 está dentro de CVCL_0080
# CVCL_0164 está dentro de CVCL_0081
# CVCL_0164 está dentro de CVCL_0082
# CVCL_0164 está dentro de CVCL_0107
# CVCL_0164 está dentro de CVCL_0110
# CVCL_0164 está dentro de CVCL_0113
# CVCL_0164 está dentro de CVCL_0115
# CVCL_0164 está dentro de CVCL_0128
# CVCL_0164 está dentro de CVCL_0135
# CVCL_0164 está dentro de CVCL_0136
# CVCL_0164 está dentro de CVCL_0138
# CVCL_0164 está dentro de CVCL_0141
# CVCL_0164 está dentro de CVCL_0144
# CVCL_0164 está dentro de CVCL_0153
# CVCL_0164 está dentro de CVCL_0165
# CVCL_0164 está dentro de CVCL_0171
# CVCL_0164 está dentro de CVCL_0181
# CVCL_0164 está dentro de CVCL_0187
# CVCL_0164 está dentro de CVCL_0193
# CVCL_0164 está dentro de CVCL_0195
# CVCL_0164 está dentro de CVCL_0196
# CVCL_0164 está dentro de CVCL_0197
# CVCL_0165 está dentro de CVCL_0028
# CVCL_0165 está dentro de CVCL_0080
# CVCL_0165 está dentro de CVCL_0081
# CVCL_0165 está dentro de CVCL_0082
# CVCL_0165 está dentro de CVCL_0107
# CVCL_0165 está dentro de CVCL_0110
# CVCL_0165 está dentro de CVCL_0113
# CVCL_0165 está dentro de CVCL_0115
# CVCL_0165 está dentro de CVCL_0128
# CVCL_0165 está dentro de CVCL_0135
# CVCL_0165 está dentro de CVCL_0136
# CVCL_0165 está dentro de CVCL_0138
# CVCL_0165 está dentro de CVCL_0141
# CVCL_0165 está dentro de CVCL_0144
# CVCL_0165 está dentro de CVCL_0153
# CVCL_0165 está dentro de CVCL_0164
# CVCL_0165 está dentro de CVCL_0171
# CVCL_0165 está dentro de CVCL_0181
# CVCL_0165 está dentro de CVCL_0187
# CVCL_0165 está dentro de CVCL_0193
# CVCL_0165 está dentro de CVCL_0195
# CVCL_0165 está dentro de CVCL_0196
# CVCL_0165 está dentro de CVCL_0197
# CVCL_0171 está dentro de CVCL_0028
# CVCL_0171 está dentro de CVCL_0080
# CVCL_0171 está dentro de CVCL_0081
# CVCL_0171 está dentro de CVCL_0082
# CVCL_0171 está dentro de CVCL_0107
# CVCL_0171 está dentro de CVCL_0110
# CVCL_0171 está dentro de CVCL_0113
# CVCL_0171 está dentro de CVCL_0115
# CVCL_0171 está dentro de CVCL_0128
# CVCL_0171 está dentro de CVCL_0135
# CVCL_0171 está dentro de CVCL_0136
# CVCL_0171 está dentro de CVCL_0138
# CVCL_0171 está dentro de CVCL_0141
# CVCL_0171 está dentro de CVCL_0144
# CVCL_0171 está dentro de CVCL_0153
# CVCL_0171 está dentro de CVCL_0164
# CVCL_0171 está dentro de CVCL_0165
# CVCL_0171 está dentro de CVCL_0181
# CVCL_0171 está dentro de CVCL_0187
# CVCL_0171 está dentro de CVCL_0193
# CVCL_0171 está dentro de CVCL_0195
# CVCL_0171 está dentro de CVCL_0196
# CVCL_0171 está dentro de CVCL_0197
# CVCL_0181 está dentro de CVCL_0028
# CVCL_0181 está dentro de CVCL_0080
# CVCL_0181 está dentro de CVCL_0081
# CVCL_0181 está dentro de CVCL_0082
# CVCL_0181 está dentro de CVCL_0107
# CVCL_0181 está dentro de CVCL_0110
# CVCL_0181 está dentro de CVCL_0113
# CVCL_0181 está dentro de CVCL_0115
# CVCL_0181 está dentro de CVCL_0128
# CVCL_0181 está dentro de CVCL_0135
# CVCL_0181 está dentro de CVCL_0136
# CVCL_0181 está dentro de CVCL_0138
# CVCL_0181 está dentro de CVCL_0141
# CVCL_0181 está dentro de CVCL_0144
# CVCL_0181 está dentro de CVCL_0153
# CVCL_0181 está dentro de CVCL_0164
# CVCL_0181 está dentro de CVCL_0165
# CVCL_0181 está dentro de CVCL_0171
# CVCL_0181 está dentro de CVCL_0187
# CVCL_0181 está dentro de CVCL_0193
# CVCL_0181 está dentro de CVCL_0195
# CVCL_0181 está dentro de CVCL_0196
# CVCL_0181 está dentro de CVCL_0197
# CVCL_0187 está dentro de CVCL_0028
# CVCL_0187 está dentro de CVCL_0080
# CVCL_0187 está dentro de CVCL_0081
# CVCL_0187 está dentro de CVCL_0082
# CVCL_0187 está dentro de CVCL_0107
# CVCL_0187 está dentro de CVCL_0110
# CVCL_0187 está dentro de CVCL_0113
# CVCL_0187 está dentro de CVCL_0115
# CVCL_0187 está dentro de CVCL_0128
# CVCL_0187 está dentro de CVCL_0135
# CVCL_0187 está dentro de CVCL_0136
# CVCL_0187 está dentro de CVCL_0138
# CVCL_0187 está dentro de CVCL_0141
# CVCL_0187 está dentro de CVCL_0144
# CVCL_0187 está dentro de CVCL_0153
# CVCL_0187 está dentro de CVCL_0164
# CVCL_0187 está dentro de CVCL_0165
# CVCL_0187 está dentro de CVCL_0171
# CVCL_0187 está dentro de CVCL_0181
# CVCL_0187 está dentro de CVCL_0193
# CVCL_0187 está dentro de CVCL_0195
# CVCL_0187 está dentro de CVCL_0196
# CVCL_0187 está dentro de CVCL_0197
# CVCL_0193 está dentro de CVCL_0028
# CVCL_0193 está dentro de CVCL_0080
# CVCL_0193 está dentro de CVCL_0081
# CVCL_0193 está dentro de CVCL_0082
# CVCL_0193 está dentro de CVCL_0107
# CVCL_0193 está dentro de CVCL_0110
# CVCL_0193 está dentro de CVCL_0113
# CVCL_0193 está dentro de CVCL_0115
# CVCL_0193 está dentro de CVCL_0128
# CVCL_0193 está dentro de CVCL_0135
# CVCL_0193 está dentro de CVCL_0136
# CVCL_0193 está dentro de CVCL_0138
# CVCL_0193 está dentro de CVCL_0141
# CVCL_0193 está dentro de CVCL_0144
# CVCL_0193 está dentro de CVCL_0153
# CVCL_0193 está dentro de CVCL_0164
# CVCL_0193 está dentro de CVCL_0165
# CVCL_0193 está dentro de CVCL_0171
# CVCL_0193 está dentro de CVCL_0181
# CVCL_0193 está dentro de CVCL_0187
# CVCL_0193 está dentro de CVCL_0195
# CVCL_0193 está dentro de CVCL_0196
# CVCL_0193 está dentro de CVCL_0197
# CVCL_0195 está dentro de CVCL_0028
# CVCL_0195 está dentro de CVCL_0080
# CVCL_0195 está dentro de CVCL_0081
# CVCL_0195 está dentro de CVCL_0082
# CVCL_0195 está dentro de CVCL_0107
# CVCL_0195 está dentro de CVCL_0110
# CVCL_0195 está dentro de CVCL_0113
# CVCL_0195 está dentro de CVCL_0115
# CVCL_0195 está dentro de CVCL_0128
# CVCL_0195 está dentro de CVCL_0135
# CVCL_0195 está dentro de CVCL_0136
# CVCL_0195 está dentro de CVCL_0138
# CVCL_0195 está dentro de CVCL_0141
# CVCL_0195 está dentro de CVCL_0144
# CVCL_0195 está dentro de CVCL_0153
# CVCL_0195 está dentro de CVCL_0164
# CVCL_0195 está dentro de CVCL_0165
# CVCL_0195 está dentro de CVCL_0171
# CVCL_0195 está dentro de CVCL_0181
# CVCL_0195 está dentro de CVCL_0187
# CVCL_0195 está dentro de CVCL_0193
# CVCL_0195 está dentro de CVCL_0196
# CVCL_0195 está dentro de CVCL_0197
# CVCL_0196 está dentro de CVCL_0028
# CVCL_0196 está dentro de CVCL_0080
# CVCL_0196 está dentro de CVCL_0081
# CVCL_0196 está dentro de CVCL_0082
# CVCL_0196 está dentro de CVCL_0107
# CVCL_0196 está dentro de CVCL_0110
# CVCL_0196 está dentro de CVCL_0113
# CVCL_0196 está dentro de CVCL_0115
# CVCL_0196 está dentro de CVCL_0128
# CVCL_0196 está dentro de CVCL_0135
# CVCL_0196 está dentro de CVCL_0136
# CVCL_0196 está dentro de CVCL_0138
# CVCL_0196 está dentro de CVCL_0141
# CVCL_0196 está dentro de CVCL_0144
# CVCL_0196 está dentro de CVCL_0153
# CVCL_0196 está dentro de CVCL_0164
# CVCL_0196 está dentro de CVCL_0165
# CVCL_0196 está dentro de CVCL_0171
# CVCL_0196 está dentro de CVCL_0181
# CVCL_0196 está dentro de CVCL_0187
# CVCL_0196 está dentro de CVCL_0193
# CVCL_0196 está dentro de CVCL_0195
# CVCL_0196 está dentro de CVCL_0197
# CVCL_0197 está dentro de CVCL_0028
# CVCL_0197 está dentro de CVCL_0080
# CVCL_0197 está dentro de CVCL_0081
# CVCL_0197 está dentro de CVCL_0082
# CVCL_0197 está dentro de CVCL_0107
# CVCL_0197 está dentro de CVCL_0110
# CVCL_0197 está dentro de CVCL_0113
# CVCL_0197 está dentro de CVCL_0115
# CVCL_0197 está dentro de CVCL_0128
# CVCL_0197 está dentro de CVCL_0135
# CVCL_0197 está dentro de CVCL_0136
# CVCL_0197 está dentro de CVCL_0138
# CVCL_0197 está dentro de CVCL_0141
# CVCL_0197 está dentro de CVCL_0144
# CVCL_0197 está dentro de CVCL_0153
# CVCL_0197 está dentro de CVCL_0164
# CVCL_0197 está dentro de CVCL_0165
# CVCL_0197 está dentro de CVCL_0171
# CVCL_0197 está dentro de CVCL_0181
# CVCL_0197 está dentro de CVCL_0187
# CVCL_0197 está dentro de CVCL_0193
# CVCL_0197 está dentro de CVCL_0195
# CVCL_0197 está dentro de CVCL_0196
